# %% [markdown]
# # Feature Engineering

# %%
df = df.drop('collector.id', axis=1)

# %%
df
# Out:
#      c.score   l.score      rain  tree.age  surface.litter  wind.intensity  \
# 0     13.110  3.421591  0.477187     34.66        6.718047        3.335635
# 1     11.990  2.874611  0.212425     19.39        6.242029        3.127024
# 2     12.910  2.827774  0.118141     15.75        6.397929        3.052446
# 3     12.060  2.772961  0.097565     13.25        6.278146        3.114239
# 4     15.060  3.271684  0.438121     47.14        6.932448        3.214831
# ..       ...       ...       ...       ...             ...             ...
# 451   11.340  2.865292  0.094384     16.41        6.250168        3.271296
# 452   13.700  2.847752  0.157058     20.64        6.531606        3.087569
# 453    9.720  2.718282  0.000000     21.69        5.716370        2.926373
# 454   13.170  2.962686  0.261034     14.49        6.607596        3.196904
# 455    9.847  2.783123  0.120080     15.24        5.930918        3.165976
#
#      humidity  tree.density  month time.of.day  fire
# ...

# %% [markdown]
# Dropped 'collector.id' feature as it does not contribute significantly to prediction accuracy.

# %%
targetname ="fire"
allfeaturenames = df.columns[df.columns!=targetname]
x = df[allfeaturenames]
y= df[targetname]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# Split the data into train-test and allocating the features and target variables

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import numpy as np
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [9])], remainder='passthrough')

# Fit and transform X_train
x_train = np.array(ct.fit_transform(x_train))

# Transform X_test
x_test = np.array(ct.transform(x_test))

# %% [markdown]
# Transforming Catergorical Variable 'time.of.day' into Numerical variable

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train[:,9:]=sc.fit_transform(x_train[:,9:])
x_test[:,9:]=sc.transform(x_test[:,9:])

# %% [markdown]
# Using Standard Scaler to Standardize the dataset.
# Standardization transforms data to have a mean of 0 and a standard deviation of 1, ensuring features contribute equally to model performance.
