# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# Import Libraries

# %%
df=pd.read_csv('forestdata.csv')

# %% [markdown]
# Read the csv file

# %%
df
# Out:
#      collector.id  c.score   l.score      rain  tree.age  surface.litter  \
# 0               5   13.110  3.421591  0.477187     34.66        6.718047
# 1               7   11.990  2.874611  0.212425     19.39        6.242029
# 2               6   12.910  2.827774  0.118141     15.75        6.397929
# 3               5   12.060  2.772961  0.097565     13.25        6.278146
# 4               2   15.060  3.271684  0.438121     47.14        6.932448
# ..            ...      ...       ...       ...       ...             ...
# 451             5   11.340  2.865292  0.094384     16.41        6.250168
# 452            10   13.700  2.847752  0.157058     20.64        6.531606
# 453             6    9.720  2.718282  0.000000     21.69        5.716370
# 454             9   13.170  2.962686  0.261034     14.49        6.607596
# 455             8    9.847  2.783123  0.120080     15.24        5.930918
#
#      wind.intensity  humidity  tree.density  month time.of.day  fire
# ...

# %%
df.shape
# Out:
# (456, 12)

# %%
df.isnull().sum()
# Out:
# collector.id      0
# c.score           0
# l.score           1
# rain              1
# tree.age          1
# surface.litter    0
# wind.intensity    1
# humidity          3
# tree.density      0
# month             0
# time.of.day       0
# fire              0
# dtype: int64

# %%
df["tree.age"].fillna(df["tree.age"].mean(), inplace=True)
df["l.score"].fillna(df["l.score"].mean(), inplace=True)
df["rain"].fillna(df["rain"].mean(), inplace=True)
df["wind.intensity"].fillna(df["wind.intensity"].mean(), inplace=True)
df["humidity"].fillna(df["humidity"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# collector.id      0
# c.score           0
# l.score           0
# rain              0
# tree.age          0
# surface.litter    0
# wind.intensity    0
# humidity          0
# tree.density      0
# month             0
# time.of.day       0
# fire              0
# dtype: int64

# %% [markdown]
# We can check that there are missing values and we have treated them by replacing the mean or average of that particular feature,
# We took the mean instead of dropping the rows as it is a small dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   collector.id    456 non-null    int64
#  1   c.score         456 non-null    float64
#  2   l.score         456 non-null    float64
#  3   rain            456 non-null    float64
#  4   tree.age        456 non-null    float64
#  5   surface.litter  456 non-null    float64
#  6   wind.intensity  456 non-null    float64
#  7   humidity        456 non-null    float64
#  8   tree.density    456 non-null    float64
#  9   month           456 non-null    int64
#  10  time.of.day     456 non-null    object
#  11  fire            456 non-null    int64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 42.9+ KB

# %% [markdown]
# To check the Categorical and Numerical Variables of our dataset.

# %%
df.describe()
# Out:
#        collector.id      c.score     l.score        rain    tree.age  \
# count    456.000000   456.000000  456.000000  456.000000  456.000000
# mean       5.730263    22.857656    3.010865    0.245926   41.681767
# std        2.921622   130.770478    0.317118    0.200712   49.005233
# min        1.000000     6.981000    2.718282    0.000000    6.802000
# 25%        3.000000    11.697500    2.796784    0.096185   17.740000
# 50%        6.000000    13.275000    2.888916    0.165880   24.610000
# 75%        8.000000    16.040000    3.121864    0.379038   45.405000
# max       11.000000  1990.200000    4.629025    1.000000  542.200000
#
#        surface.litter  wind.intensity    humidity  tree.density       month  \
# count      456.000000      456.000000  456.000000    456.000000  456.000000
# mean         6.623185        3.132817   56.231788      0.613652    6.732456
# std          0.563944        0.081246    6.101821      0.067054    3.429465
# ...

# %% [markdown]
# df.describe() to check the Statistics of the dataset.

# %% [markdown]
# # Data Visualization

# %%
df.hist(figsize = (15,20))
# Out:
# array([[<Axes: title={'center': 'collector.id'}>,
#         <Axes: title={'center': 'c.score'}>,
#         <Axes: title={'center': 'l.score'}>],
#        [<Axes: title={'center': 'rain'}>,
#         <Axes: title={'center': 'tree.age'}>,
#         <Axes: title={'center': 'surface.litter'}>],
#        [<Axes: title={'center': 'wind.intensity'}>,
#         <Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'tree.density'}>],
#        [<Axes: title={'center': 'month'}>,
#         <Axes: title={'center': 'fire'}>, <Axes: >]], dtype=object)

# %%
df['time.of.day'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['time.of.day'] = df['time.of.day'].replace({'morni7ng': 'morning'})
df['time.of.day'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Corrected the spelling error in the dataset
